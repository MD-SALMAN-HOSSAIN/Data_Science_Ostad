# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(11)
y1 = x + 2
y2 = x + 3

plt.plot(x, y1, label='y = x + 2')
plt.plot(x, y2, label='y = x + 3')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Line Chart: y = x + 2 and y = x + 3')
plt.grid(False)
plt.show()
