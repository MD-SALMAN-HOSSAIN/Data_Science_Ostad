# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
data_dic = {'A':[89,15,60,71],
            'B':[18,26,50,80],
            'C':[32,48,78,93],
            'D':[29,35,63,81]}
Heat = pd.DataFrame(data_dic)
Heat
sns.heatmap(Heat, annot=True)
# Out:
# <Axes: >
